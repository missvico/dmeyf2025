# %%
#import pandas as pd NO LO USAMOS MAS
import gzip
import polars as pl
import numpy as np

# %% [markdown]
# ## Leer data

# %%
def read_polar(path):
    # Ruta al archivo — importante usar r"" para evitar problemas con backslashes en Windows
    #path = r"G:\My Drive\dmeyf\competencia_02_crudo.csv.gz"

    # Leer el CSV comprimido
    dataset = pl.read_csv(
        path,
        separator=",",            # usa ',' como separador
        has_header=True,    # primera fila son los nombres de columna
        infer_schema_length=5000,  # lee más filas para detectar bien los tipos
        ignore_errors=True, # salta filas corruptas si las hubiera
        low_memory=True     # usa menos RAM si el archivo es grande
    )

    #print(dataset.shape)
    #print(dataset.head())
    return dataset

def write_polar_gz(dataset,path_target):
    # === 7. Guardar resultado ===
    with gzip.open(path_target, "wt", encoding="utf-8") as f:
        dataset.write_csv(f)
    return

def generar_ternaria(dataset):
    # === 2. Calcular periodo0 consecutivo ===
    dataset = dataset.with_columns(
        ((pl.col("foto_mes") // 100) * 12 + (pl.col("foto_mes") % 100)).alias("periodo0")
    )

    # === 3. Calcular leads (mes siguiente y subsiguiente) por cliente ===
    dsimple = (
        dataset
        .sort(["numero_de_cliente", "periodo0"])
        .with_columns([
            pl.col("periodo0").shift(-1).over("numero_de_cliente").alias("periodo1"),
            pl.col("periodo0").shift(-2).over("numero_de_cliente").alias("periodo2"),
        ])
    )

    # === 4. Calcular topes ===
    periodo_ultimo = dsimple["periodo0"].max()
    periodo_anteultimo = periodo_ultimo - 1

    # === 5. Crear columna clase_ternaria ===
    #   Regla base: CONTINUA
    #   Luego se sobrescriben BAJA+1 y BAJA+2

    dsimple = dsimple.with_columns(pl.lit(None).alias("clase_ternaria"))

    dsimple = dsimple.with_columns(
        pl.when(pl.col("periodo0") < periodo_anteultimo)
        .then(pl.lit("CONTINUA"))              # ← pl.lit() asegura que es un valor literal
        .otherwise(pl.col("clase_ternaria"))
        .alias("clase_ternaria")
    )

    dsimple = dsimple.with_columns(
        pl.when(
            (pl.col("periodo0") < periodo_ultimo) &
            ((pl.col("periodo1").is_null()) | (pl.col("periodo0") + 1 < pl.col("periodo1")))
        )
        .then(pl.lit("BAJA+1"))                   # ← ¡usa pl.lit()!
        .otherwise(pl.col("clase_ternaria"))
        .alias("clase_ternaria")
    )

    dsimple = dsimple.with_columns(
        pl.when(
            (pl.col("periodo0") < periodo_anteultimo) &
            (pl.col("periodo0") + 1 == pl.col("periodo1")) &
            ((pl.col("periodo2").is_null()) | (pl.col("periodo0") + 2 < pl.col("periodo2")))
        )
        .then(pl.lit("BAJA+2"))                     # ← usar pl.lit() siempre
        .otherwise(pl.col("clase_ternaria"))
        .alias("clase_ternaria")
    )

    # === 6. Reinsertar en dataset original ===
    dataset = (
        dataset.join(
            dsimple.select(["numero_de_cliente", "periodo0", "clase_ternaria"]),
            on=["numero_de_cliente", "periodo0"],
            how="left"
        )
    )
    return dataset

def generar_columna_target(dataset):
    # target = 1 si clase_ternaria ∈ ["BAJA+1", "BAJA+2"], sino 0
    dataset = dataset.with_columns([
        pl.col("clase_ternaria")
          .is_in(["BAJA+1", "BAJA+2"])
          .cast(pl.Int8)
          .alias("target"),
    
        # clase_peso = 1.0
        pl.lit(1.0).alias("clase_peso")
    ])
    return dataset

def generar_delta_lags(dataset):
    # Ordenar por cliente y mes (igual que sort_values)
    dataset = dataset.sort(["numero_de_cliente", "foto_mes"])
    
    exclude_cols = {"numero_de_cliente", "foto_mes", "clase_ternaria", "target", "clase_peso"}
    
    numeric_types = (
        pl.Int8, pl.Int16, pl.Int32, pl.Int64,
        pl.UInt8, pl.UInt16, pl.UInt32, pl.UInt64,
        pl.Float32, pl.Float64
    )
    
    fe_cols = [
        c for c, dtype in zip(dataset.columns, dataset.dtypes)
        if c not in exclude_cols and isinstance(dtype, numeric_types)
    ]
    
    #print(f"Columnas numéricas seleccionadas: {len(fe_cols)}")
    
    # Paso 1: crear los lagN
    for n in [1, 2]:
        lag_exprs = [
            pl.col(c).shift(n).over("numero_de_cliente").alias(f"{c}_lag{n}")
            for c in fe_cols
        ]
        dataset = dataset.with_columns(lag_exprs)
    
    # Paso 2: crear los dlagN (una vez que ya existen los lagN)
    for n in [1, 2]:
        dlag_exprs = [
            (pl.col(c) - pl.col(f"{c}_lag{n}")).alias(f"{c}_dlag{n}")
            for c in fe_cols
        ]
        dataset = dataset.with_columns(dlag_exprs)
    
    print(f"Lags/deltas agregados: {len(fe_cols)*2}")
    return dataset

def lgb_gan_eval(y_pred, data):
    weight = data.get_weight()
    ganancia = np.where(weight == 1.00002, ganancia_acierto, 0) - np.where(weight < 1.00002, costo_estimulo, 0)
    ganancia = ganancia[np.argsort(y_pred)[::-1]]
    ganancia = np.cumsum(ganancia)

    return 'gan_eval', np.max(ganancia) , True

def undersampling_experimento(dataset,undersampling,train_months,seed):
    # --- parámetros de entrenamiento ---  
    dataset = dataset.filter(pl.col("foto_mes").is_in(train_months))

    # --- generar la columna azar reproducible ---
    rng = np.random.default_rng(seed)
    dataset = dataset.with_columns(
        pl.Series("azar", rng.random(len(dataset)))  # uniforme entre 0 y 1
    )
    
    # --- inicializar columna training ---
    dataset = dataset.with_columns(pl.lit(0).alias("training"))
    
    # --- aplicar la misma condición que en R ---
    dataset = dataset.with_columns(
        pl.when(
                (pl.col("azar") <= undersampling) |
                (pl.col("clase_ternaria").is_in(["BAJA+1", "BAJA+2"]))
        )
        .then(1)
        .otherwise(0)
        .alias("training")
    )
    
    # --- chequeo ---
    print(dataset.select(pl.col("training")).to_series().value_counts())
    print(dataset.group_by(["training", "clase_ternaria"]).len().sort("training"))
    return dataset

def convertirpercentil(dataset):
    # --- 1️⃣ Ordenar por fecha y cliente
    dataset = dataset.sort(["foto_mes", "numero_de_cliente"])
    
    # --- 2️⃣ Detectar columnas numéricas (excepto las de control)
    exclude_cols = {"numero_de_cliente", "foto_mes", "clase_ternaria", "target", "clase_peso"}
    
    numeric_types = (
        pl.Int8, pl.Int16, pl.Int32, pl.Int64,
        pl.UInt8, pl.UInt16, pl.UInt32, pl.UInt64,
        pl.Float32, pl.Float64
    )
    
    num_cols = [
        c for c, dtype in dataset.schema.items()
        if c not in exclude_cols and dtype in numeric_types
    ]
    
    #print(f"Columnas numéricas detectadas: {num_cols}")
    
    # --- 3️⃣ Función auxiliar: percentil dentro del grupo de foto_mes
    def to_percentile_expr(col):
        # rank() / count() * 100 → percentil [0,100]
        return (pl.col(col).rank("average") / pl.count() * 100).cast(pl.Float32)
    
    # --- 4️⃣ Aplicar transformación por grupo de foto_mes
    for c in num_cols:
        new_col = f"{c}_pctl"
        dataset = (
            dataset.with_columns(
                to_percentile_expr(c).over("foto_mes").alias(new_col)
            )
            .drop(c)  # quitar la original; si querés mantenerla, eliminá esta línea
        )
        #print(f"✅ Convertida {c} → {new_col}")
    
    print(f"\nTotal columnas convertidas: {len(num_cols)}")
    return dataset

# %%
#La primera vez ejecuten esste y despues comenten
path = "../datasets/competencia_02_crudo.csv.gz"
dataset = read_polar(path)
dataset = generar_ternaria(dataset)
dataset = generar_columna_target(dataset)
dataset = generar_delta_lags(dataset)
dataset = convertirpercentil(dataset)
#path_target = "../datasets/competencia_02.csv.gz"
#write_polar_gz(dataset,path_target)

resumen = (
    dataset
    .group_by(["foto_mes", "clase_ternaria"])
    .agg(pl.count().alias("cantidad"))
    .sort(["foto_mes", "clase_ternaria"])
)

pivot = resumen.pivot(
    values="cantidad",
    index="foto_mes",
    columns="clase_ternaria"
).fill_null(0)

print(pivot)
#pivot.write_csv("output.csv")
# Out:
# Lags/deltas agregados: 302
# Columnas numéricas detectadas: ['active_quarter', 'cliente_vip', 'internet', 'cliente_edad', 'cliente_antiguedad', 'mrentabilidad', 'mrentabilidad_annual', 'mcomisiones', 'mactivos_margen', 'mpasivos_margen', 'cproductos', 'tcuentas', 'ccuenta_corriente', 'mcuenta_corriente_adicional', 'mcuenta_corriente', 'ccaja_ahorro', 'mcaja_ahorro', 'mcaja_ahorro_adicional', 'mcaja_ahorro_dolares', 'cdescubierto_preacordado', 'mcuentas_saldo', 'ctarjeta_debito', 'ctarjeta_debito_transacciones', 'mautoservicio', 'ctarjeta_visa', 'ctarjeta_visa_transacciones', 'mtarjeta_visa_consumo', 'ctarjeta_master', 'ctarjeta_master_transacciones', 'mtarjeta_master_consumo', 'cprestamos_personales', 'mprestamos_personales', 'cprestamos_prendarios', 'mprestamos_prendarios', 'cprestamos_hipotecarios', 'mprestamos_hipotecarios', 'cplazo_fijo', 'mplazo_fijo_dolares', 'mplazo_fijo_pesos', 'cinversion1', 'minversion1_pesos', 'minversion1_dolares', 'cinversion2', 'minversion2', 'cseguro_vida', 'cseguro_auto', 'cseguro_vivienda', 'cseguro_accidentes_personales', 'ccaja_seguridad', 'cpayroll_trx', 'mpayroll', 'mpayroll2', 'cpayroll2_trx', 'ccuenta_debitos_automaticos', 'mcuenta_debitos_automaticos', 'ctarjeta_visa_debitos_automaticos', 'mttarjeta_visa_debitos_automaticos', 'ctarjeta_master_debitos_automaticos', 'mttarjeta_master_debitos_automaticos', 'cpagodeservicios', 'mpagodeservicios', 'cpagomiscuentas', 'mpagomiscuentas', 'ccajeros_propios_descuentos', 'mcajeros_propios_descuentos', 'ctarjeta_visa_descuentos', 'mtarjeta_visa_descuentos', 'ctarjeta_master_descuentos', 'mtarjeta_master_descuentos', 'ccomisiones_mantenimiento', 'mcomisiones_mantenimiento', 'ccomisiones_otras', 'mcomisiones_otras', 'cforex', 'cforex_buy', 'mforex_buy', 'cforex_sell', 'mforex_sell', 'ctransferencias_recibidas', 'mtransferencias_recibidas', 'ctransferencias_emitidas', 'mtransferencias_emitidas', 'cextraccion_autoservicio', 'mextraccion_autoservicio', 'ccheques_depositados', 'mcheques_depositados', 'ccheques_emitidos', 'mcheques_emitidos', 'ccheques_depositados_rechazados', 'mcheques_depositados_rechazados', 'ccheques_emitidos_rechazados', 'mcheques_emitidos_rechazados', 'tcallcenter', 'ccallcenter_transacciones', 'thomebanking', 'chomebanking_transacciones', 'ccajas_transacciones', 'ccajas_consultas', 'ccajas_depositos', 'ccajas_extracciones', 'ccajas_otras', 'catm_trx', 'matm', 'catm_trx_other', 'matm_other', 'ctrx_quarter', 'Master_delinquency', 'Master_status', 'Master_mfinanciacion_limite', 'Master_Fvencimiento', 'Master_Finiciomora', 'Master_msaldototal', 'Master_msaldopesos', 'Master_msaldodolares', 'Master_mconsumospesos', 'Master_mconsumosdolares', 'Master_mlimitecompra', 'Master_madelantopesos', 'Master_madelantodolares', 'Master_fultimo_cierre', 'Master_mpagado', 'Master_mpagospesos', 'Master_mpagosdolares', 'Master_fechaalta', 'Master_mconsumototal', 'Master_cconsumos', 'Master_cadelantosefectivo', 'Master_mpagominimo', 'Visa_delinquency', 'Visa_status', 'Visa_mfinanciacion_limite', 'Visa_Fvencimiento', 'Visa_Finiciomora', 'Visa_msaldototal', 'Visa_msaldopesos', 'Visa_msaldodolares', 'Visa_mconsumospesos', 'Visa_mconsumosdolares', 'Visa_mlimitecompra', 'Visa_madelantopesos', 'Visa_madelantodolares', 'Visa_fultimo_cierre', 'Visa_mpagado', 'Visa_mpagospesos', 'Visa_mpagosdolares', 'Visa_fechaalta', 'Visa_mconsumototal', 'Visa_cconsumos', 'Visa_cadelantosefectivo', 'Visa_mpagominimo', 'periodo0', 'active_quarter_lag1', 'cliente_vip_lag1', 'internet_lag1', 'cliente_edad_lag1', 'cliente_antiguedad_lag1', 'mrentabilidad_lag1', 'mrentabilidad_annual_lag1', 'mcomisiones_lag1', 'mactivos_margen_lag1', 'mpasivos_margen_lag1', 'cproductos_lag1', 'tcuentas_lag1', 'ccuenta_corriente_lag1', 'mcuenta_corriente_adicional_lag1', 'mcuenta_corriente_lag1', 'ccaja_ahorro_lag1', 'mcaja_ahorro_lag1', 'mcaja_ahorro_adicional_lag1', 'mcaja_ahorro_dolares_lag1', 'cdescubierto_preacordado_lag1', 'mcuentas_saldo_lag1', 'ctarjeta_debito_lag1', 'ctarjeta_debito_transacciones_lag1', 'mautoservicio_ ...
# ✅ Convertida active_quarter → active_quarter_pctl
# /tmp/ipykernel_2895/3524049700.py:200: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   return (pl.col(col).rank("average") / pl.count() * 100).cast(pl.Float32)
# ✅ Convertida cliente_vip → cliente_vip_pctl
# ✅ Convertida internet → internet_pctl
# ✅ Convertida cliente_edad → cliente_edad_pctl
# ✅ Convertida cliente_antiguedad → cliente_antiguedad_pctl
# ✅ Convertida mrentabilidad → mrentabilidad_pctl
# ✅ Convertida mrentabilidad_annual → mrentabilidad_annual_pctl
# ✅ Convertida mcomisiones → mcomisiones_pctl
# ✅ Convertida mactivos_margen → mactivos_margen_pctl
# ✅ Convertida mpasivos_margen → mpasivos_margen_pctl
# ✅ Convertida cproductos → cproductos_pctl
# ✅ Convertida tcuentas → tcuentas_pctl
# ✅ Convertida ccuenta_corriente → ccuenta_corriente_pctl
# ✅ Convertida mcuenta_corriente_adicional → mcuenta_corriente_adicional_pctl
# ✅ Convertida mcuenta_corriente → mcuenta_corriente_pctl
# ✅ Convertida ccaja_ahorro → ccaja_ahorro_pctl
# ✅ Convertida mcaja_ahorro → mcaja_ahorro_pctl
# ✅ Convertida mcaja_ahorro_adicional → mcaja_ahorro_adicional_pctl
# ✅ Convertida mcaja_ahorro_dolares → mcaja_ahorro_dolares_pctl
# ✅ Convertida cdescubierto_preacordado → cdescubierto_preacordado_pctl
# ✅ Convertida mcuentas_saldo → mcuentas_saldo_pctl
# ✅ Convertida ctarjeta_debito → ctarjeta_debito_pctl
# ✅ Convertida ctarjeta_debito_transacciones → ctarjeta_debito_transacciones_pctl
# ✅ Convertida mautoservicio → mautoservicio_pctl
# ✅ Convertida ctarjeta_visa → ctarjeta_visa_pctl
# ✅ Convertida ctarjeta_visa_transacciones → ctarjeta_visa_transacciones_pctl
# ✅ Convertida mtarjeta_visa_consumo → mtarjeta_visa_consumo_pctl
# ✅ Convertida ctarjeta_master → ctarjeta_master_pctl
# ✅ Convertida ctarjeta_master_transacciones → ctarjeta_master_transacciones_pctl
# ✅ Convertida mtarjeta_master_consumo → mtarjeta_master_consumo_pctl
# ✅ Convertida cprestamos_personales → cprestamos_personales_pctl
# ✅ Convertida mprestamos_personales → mprestamos_personales_pctl
# ✅ Convertida cprestamos_prendarios → cprestamos_prendarios_pctl
# ✅ Convertida mprestamos_prendarios → mprestamos_prendarios_pctl
# ✅ Convertida cprestamos_hipotecarios → cprestamos_hipotecarios_pctl
# ✅ Convertida mprestamos_hipotecarios → mprestamos_hipotecarios_pctl
# ✅ Convertida cplazo_fijo → cplazo_fijo_pctl
# ✅ Convertida mplazo_fijo_dolares → mplazo_fijo_dolares_pctl
# ✅ Convertida mplazo_fijo_pesos → mplazo_fijo_pesos_pctl
# ✅ Convertida cinversion1 → cinversion1_pctl
# ✅ Convertida minversion1_pesos → minversion1_pesos_pctl
# ✅ Convertida minversion1_dolares → minversion1_dolares_pctl
# ✅ Convertida cinversion2 → cinversion2_pctl
# ✅ Convertida minversion2 → minversion2_pctl
# ✅ Convertida cseguro_vida → cseguro_vida_pctl
# ✅ Convertida cseguro_auto → cseguro_auto_pctl
# ✅ Convertida cseguro_vivienda → cseguro_vivienda_pctl
# ✅ Convertida cseguro_accidentes_personales → cseguro_accidentes_personales_pctl
# ✅ Convertida ccaja_seguridad → ccaja_seguridad_pctl
# ✅ Convertida cpayroll_trx → cpayroll_trx_pctl
# ✅ Convertida mpayroll → mpayroll_pctl
# ✅ Convertida mpayroll2 → mpayroll2_pctl
# ✅ Convertida cpayroll2_trx → cpayroll2_trx_pctl
# ✅ Convertida ccuenta_debitos_automaticos → ccuenta_debitos_automaticos_pctl
# ✅ Convertida mcuenta_debitos_automaticos → mcuenta_debitos_automaticos_pctl
# ✅ Convertida ctarjeta_visa_debitos_automaticos → ctarjeta_visa_debitos_automaticos_pctl
# ✅ Convertida mttarjeta_visa_debitos_automaticos → mttarjeta_visa_debitos_automaticos_pctl
# ✅ Convertida ctarjeta_master_debitos_automaticos → ctarjeta_master_debitos_automaticos_pctl
# ✅ Convertida mttarjeta_master_debitos_automaticos → mttarjeta_master_debitos_automaticos_pctl
# ✅ Convertida cpagodeservicios → cpagodeservicios_pctl
# ✅ Convertida mpagodeservicios → mpagodeservicios_pctl
# ✅ Convertida cpagomiscuentas → cpagomiscuentas_pctl
# ✅ Convertida mpagomiscuentas → mpagomiscuentas_pctl
# ✅ Convertida ccajeros_propios_descuentos → ccajeros_propios_descuentos_pctl
# ✅ Convertida mcajeros_propios_descuentos → mcajeros_propios_descuentos_pctl
# ✅ Convertida ctarjeta_visa_descuentos → ctarjeta_visa_descuentos_pctl
# ✅ Convertida mtarjeta_visa_descuentos → mtarjeta_visa_descuentos_pctl
# ✅ Convertida ctarjeta_master_descuentos → ctarjeta_master_descuentos_pctl
# ✅ Convertida mtarjeta_master_descuentos → mtarjeta_master_descuentos_pctl
# ✅ Convertida ccomisiones_mantenimiento → ccomisiones_mantenimiento_pctl
# ✅ Convertida mcomisiones_mantenimiento → mcomisiones_mantenimiento_pctl
# ✅ Convertida ccomisiones_otras → ccomisiones_otras_pctl
# ✅ Convertida mcomisiones_otras → mcomisiones_otras_pctl
# ✅ Convertida cforex → cforex_pctl
# ✅ Convertida cforex_buy → cforex_buy_pctl
# ✅ Convertida mforex_buy → mforex_buy_pctl
# ✅ Convertida cforex_sell → cforex_sell_pctl
# ✅ Convertida mforex_sell → mforex_sell_pctl
# ✅ Convertida ctransferencias_recibidas → ctransferencias_recibidas_pctl
# ✅ Convertida mtransferencias_recibidas → mtransferencias_recibidas_pctl
# ✅ Convertida ctransferencias_emitidas → ctransferencias_emitidas_pctl
# ✅ Convertida mtransferencias_emitidas → mtransferencias_emitidas_pctl
# ✅ Convertida cextraccion_autoservicio → cextraccion_autoservicio_pctl
# ✅ Convertida mextraccion_autoservicio → mextraccion_autoservicio_pctl
# ✅ Convertida ccheques_depositados → ccheques_depositados_pctl
# ✅ Convertida mcheques_depositados → mcheques_depositados_pctl
# ✅ Convertida ccheques_emitidos → ccheques_emitidos_pctl
# ✅ Convertida mcheques_emitidos → mcheques_emitidos_pctl
# ✅ Convertida ccheques_depositados_rechazados → ccheques_depositados_rechazados_pctl
# ✅ Convertida mcheques_depositados_rechazados → mcheques_depositados_rechazados_pctl
# ✅ Convertida ccheques_emitidos_rechazados → ccheques_emitidos_rechazados_pctl
# ✅ Convertida mcheques_emitidos_rechazados → mcheques_emitidos_rechazados_pctl
# ✅ Convertida tcallcenter → tcallcenter_pctl
# ✅ Convertida ccallcenter_transacciones → ccallcenter_transacciones_pctl
# ✅ Convertida thomebanking → thomebanking_pctl
# ✅ Convertida chomebanking_transacciones → chomebanking_transacciones_pctl
# ✅ Convertida ccajas_transacciones → ccajas_transacciones_pctl
# ✅ Convertida ccajas_consultas → ccajas_consultas_pctl
# ✅ Convertida ccajas_depositos → ccajas_depositos_pctl
# ✅ Convertida ccajas_extracciones → ccajas_extracciones_pctl
# ✅ Convertida ccajas_otras → ccajas_otras_pctl
# ✅ Convertida catm_trx → catm_trx_pctl
# ✅ Convertida matm → matm_pctl
# ✅ Convertida catm_trx_other → catm_trx_other_pctl
# ✅ Convertida matm_other → matm_other_pctl
# ✅ Convertida ctrx_quarter → ctrx_quarter_pctl
# ✅ Convertida Master_delinquency → Master_delinquency_pctl
# ✅ Convertida Master_status → Master_status_pctl
# ✅ Convertida Master_mfinanciacion_limite → Master_mfinanciacion_limite_pctl
# ✅ Convertida Master_Fvencimiento → Master_Fvencimiento_pctl
# ✅ Convertida Master_Finiciomora → Master_Finiciomora_pctl
# ✅ Convertida Master_msaldototal → Master_msaldototal_pctl
# ✅ Convertida Master_msaldopesos → Master_msaldopesos_pctl
# ✅ Convertida Master_msaldodolares → Master_msaldodolares_pctl
# ✅ Convertida Master_mconsumospesos → Master_mconsumospesos_pctl
# ✅ Convertida Master_mconsumosdolares → Master_mconsumosdolares_pctl
# ✅ Convertida Master_mlimitecompra → Master_mlimitecompra_pctl
# ✅ Convertida Master_madelantopesos → Master_madelantopesos_pctl
# ✅ Convertida Master_madelantodolares → Master_madelantodolares_pctl
# ✅ Convertida Master_fultimo_cierre → Master_fultimo_cierre_pctl
# ✅ Convertida Master_mpagado → Master_mpagado_pctl
# ✅ Convertida Master_mpagospesos → Master_mpagospesos_pctl
# ✅ Convertida Master_mpagosdolares → Master_mpagosdolares_pctl
# ✅ Convertida Master_fechaalta → Master_fechaalta_pctl
# ✅ Convertida Master_mconsumototal → Master_mconsumototal_pctl
# ✅ Convertida Master_cconsumos → Master_cconsumos_pctl
# ✅ Convertida Master_cadelantosefectivo → Master_cadelantosefectivo_pctl
# ✅ Convertida Master_mpagominimo → Master_mpagominimo_pctl
# ✅ Convertida Visa_delinquency → Visa_delinquency_pctl
# ✅ Convertida Visa_status → Visa_status_pctl
# ✅ Convertida Visa_mfinanciacion_limite → Visa_mfinanciacion_limite_pctl
# ✅ Convertida Visa_Fvencimiento → Visa_Fvencimiento_pctl
# ✅ Convertida Visa_Finiciomora → Visa_Finiciomora_pctl
# ✅ Convertida Visa_msaldototal → Visa_msaldototal_pctl
# ✅ Convertida Visa_msaldopesos → Visa_msaldopesos_pctl
# ✅ Convertida Visa_msaldodolares → Visa_msaldodolares_pctl
# ✅ Convertida Visa_mconsumospesos → Visa_mconsumospesos_pctl
# ✅ Convertida Visa_mconsumosdolares → Visa_mconsumosdolares_pctl
# ✅ Convertida Visa_mlimitecompra → Visa_mlimitecompra_pctl
# ✅ Convertida Visa_madelantopesos → Visa_madelantopesos_pctl
# ✅ Convertida Visa_madelantodolares → Visa_madelantodolares_pctl
# ✅ Convertida Visa_fultimo_cierre → Visa_fultimo_cierre_pctl
# ✅ Convertida Visa_mpagado → Visa_mpagado_pctl
# ✅ Convertida Visa_mpagospesos → Visa_mpagospesos_pctl
# ✅ Convertida Visa_mpagosdolares → Visa_mpagosdolares_pctl
# ✅ Convertida Visa_fechaalta → Visa_fechaalta_pctl
# ✅ Convertida Visa_mconsumototal → Visa_mconsumototal_pctl
# ✅ Convertida Visa_cconsumos → Visa_cconsumos_pctl
# ✅ Convertida Visa_cadelantosefectivo → Visa_cadelantosefectivo_pctl
# ✅ Convertida Visa_mpagominimo → Visa_mpagominimo_pctl
# ✅ Convertida periodo0 → periodo0_pctl
# ✅ Convertida active_quarter_lag1 → active_quarter_lag1_pctl
# ✅ Convertida cliente_vip_lag1 → cliente_vip_lag1_pctl
# ✅ Convertida internet_lag1 → internet_lag1_pctl
# ✅ Convertida cliente_edad_lag1 → cliente_edad_lag1_pctl
# ✅ Convertida cliente_antiguedad_lag1 → cliente_antiguedad_lag1_pctl
# ✅ Convertida mrentabilidad_lag1 → mrentabilidad_lag1_pctl
# ✅ Convertida mrentabilidad_annual_lag1 → mrentabilidad_annual_lag1_pctl
# ✅ Convertida mcomisiones_lag1 → mcomisiones_lag1_pctl
# ✅ Convertida mactivos_margen_lag1 → mactivos_margen_lag1_pctl
# ✅ Convertida mpasivos_margen_lag1 → mpasivos_margen_lag1_pctl
# ✅ Convertida cproductos_lag1 → cproductos_lag1_pctl
# ✅ Convertida tcuentas_lag1 → tcuentas_lag1_pctl
# ✅ Convertida ccuenta_corriente_lag1 → ccuenta_corriente_lag1_pctl
# ✅ Convertida mcuenta_corriente_adicional_lag1 → mcuenta_corriente_adicional_lag1_pctl
# ✅ Convertida mcuenta_corriente_lag1 → mcuenta_corriente_lag1_pctl
# ✅ Convertida ccaja_ahorro_lag1 → ccaja_ahorro_lag1_pctl
# ✅ Convertida mcaja_ahorro_lag1 → mcaja_ahorro_lag1_pctl
# ✅ Convertida mcaja_ahorro_adicional_lag1 → mcaja_ahorro_adicional_lag1_pctl
# ✅ Convertida mcaja_ahorro_dolares_lag1 → mcaja_ahorro_dolares_lag1_pctl
# ✅ Convertida cdescubierto_preacordado_lag1 → cdescubierto_preacordado_lag1_pctl
# ✅ Convertida mcuentas_saldo_lag1 → mcuentas_saldo_lag1_pctl
# ✅ Convertida ctarjeta_debito_lag1 → ctarjeta_debito_lag1_pctl
# ✅ Convertida ctarjeta_debito_transacciones_lag1 → ctarjeta_debito_transacciones_lag1_pctl
# ✅ Convertida mautoservicio_lag1 → mautoservicio_lag1_pctl
# ✅ Convertida ctarjeta_visa_lag1 → ctarjeta_visa_lag1_pctl
# ✅ Convertida ctarjeta_visa_transacciones_lag1 → ctarjeta_visa_transacciones_lag1_pctl
# ✅ Convertida mtarjeta_visa_consumo_lag1 → mtarjeta_visa_consumo_lag1_pctl
# ✅ Convertida ctarjeta_master_lag1 → ctarjeta_master_lag1_pctl
# ✅ Convertida ctarjeta_master_transacciones_lag1 → ctarjeta_master_transacciones_lag1_pctl
# ✅ Convertida mtarjeta_master_consumo_lag1 → mtarjeta_master_consumo_lag1_pctl
# ✅ Convertida cprestamos_personales_lag1 → cprestamos_personales_lag1_pctl
# ✅ Convertida mprestamos_personales_lag1 → mprestamos_personales_lag1_pctl
# ✅ Convertida cprestamos_prendarios_lag1 → cprestamos_prendarios_lag1_pctl
# ✅ Convertida mprestamos_prendarios_lag1 → mprestamos_prendarios_lag1_pctl
# ✅ Convertida cprestamos_hipotecarios_lag1 → cprestamos_hipotecarios_lag1_pctl
# ✅ Convertida mprestamos_hipotecarios_lag1 → mprestamos_hipotecarios_lag1_pctl
# ✅ Convertida cplazo_fijo_lag1 → cplazo_fijo_lag1_pctl
# ✅ Convertida mplazo_fijo_dolares_lag1 → mplazo_fijo_dolares_lag1_pctl
# ✅ Convertida mplazo_fijo_pesos_lag1 → mplazo_fijo_pesos_lag1_pctl
# ✅ Convertida cinversion1_lag1 → cinversion1_lag1_pctl
# ✅ Convertida minversion1_pesos_lag1 → minversion1_pesos_lag1_pctl
# ✅ Convertida minversion1_dolares_lag1 → minversion1_dolares_lag1_pctl
# ✅ Convertida cinversion2_lag1 → cinversion2_lag1_pctl
# ✅ Convertida minversion2_lag1 → minversion2_lag1_pctl
# ✅ Convertida cseguro_vida_lag1 → cseguro_vida_lag1_pctl
# ✅ Convertida cseguro_auto_lag1 → cseguro_auto_lag1_pctl
# ✅ Convertida cseguro_vivienda_lag1 → cseguro_vivienda_lag1_pctl
# ✅ Convertida cseguro_accidentes_personales_lag1 → cseguro_accidentes_personales_lag1_pctl
# ✅ Convertida ccaja_seguridad_lag1 → ccaja_seguridad_lag1_pctl
# ✅ Convertida cpayroll_trx_lag1 → cpayroll_trx_lag1_pctl
# ✅ Convertida mpayroll_lag1 → mpayroll_lag1_pctl
# ✅ Convertida mpayroll2_lag1 → mpayroll2_lag1_pctl
# ✅ Convertida cpayroll2_trx_lag1 → cpayroll2_trx_lag1_pctl
# ✅ Convertida ccuenta_debitos_automaticos_lag1 → ccuenta_debitos_automaticos_lag1_pctl
# ✅ Convertida mcuenta_debitos_automaticos_lag1 → mcuenta_debitos_automaticos_lag1_pctl
# ✅ Convertida ctarjeta_visa_debitos_automaticos_lag1 → ctarjeta_visa_debitos_automaticos_lag1_pctl
# ✅ Convertida mttarjeta_visa_debitos_automaticos_lag1 → mttarjeta_visa_debitos_automaticos_lag1_pctl
# ✅ Convertida ctarjeta_master_debitos_automaticos_lag1 → ctarjeta_master_debitos_automaticos_lag1_pctl
# ✅ Convertida mttarjeta_master_debitos_automaticos_lag1 → mttarjeta_master_debitos_automaticos_lag1_pctl
# ✅ Convertida cpagodeservicios_lag1 → cpagodeservicios_lag1_pctl
# ✅ Convertida mpagodeservicios_lag1 → mpagodeservicios_lag1_pctl
# ✅ Convertida cpagomiscuentas_lag1 → cpagomiscuentas_lag1_pctl
# ✅ Convertida mpagomiscuentas_lag1 → mpagomiscuentas_lag1_pctl
# ✅ Convertida ccajeros_propios_descuentos_lag1 → ccajeros_propios_descuentos_lag1_pctl
# ✅ Convertida mcajeros_propios_descuentos_lag1 → mcajeros_propios_descuentos_lag1_pctl
# ✅ Convertida ctarjeta_visa_descuentos_lag1 → ctarjeta_visa_descuentos_lag1_pctl
# ✅ Convertida mtarjeta_visa_descuentos_lag1 → mtarjeta_visa_descuentos_lag1_pctl
# ✅ Convertida ctarjeta_master_descuentos_lag1 → ctarjeta_master_descuentos_lag1_pctl
# ✅ Convertida mtarjeta_master_descuentos_lag1 → mtarjeta_master_descuentos_lag1_pctl
# ✅ Convertida ccomisiones_mantenimiento_lag1 → ccomisiones_mantenimiento_lag1_pctl
# ✅ Convertida mcomisiones_mantenimiento_lag1 → mcomisiones_mantenimiento_lag1_pctl
# ✅ Convertida ccomisiones_otras_lag1 → ccomisiones_otras_lag1_pctl
# ✅ Convertida mcomisiones_otras_lag1 → mcomisiones_otras_lag1_pctl
# ✅ Convertida cforex_lag1 → cforex_lag1_pctl
# ✅ Convertida cforex_buy_lag1 → cforex_buy_lag1_pctl
# ✅ Convertida mforex_buy_lag1 → mforex_buy_lag1_pctl
# ✅ Convertida cforex_sell_lag1 → cforex_sell_lag1_pctl
# ✅ Convertida mforex_sell_lag1 → mforex_sell_lag1_pctl
# ✅ Convertida ctransferencias_recibidas_lag1 → ctransferencias_recibidas_lag1_pctl
# ✅ Convertida mtransferencias_recibidas_lag1 → mtransferencias_recibidas_lag1_pctl
# ✅ Convertida ctransferencias_emitidas_lag1 → ctransferencias_emitidas_lag1_pctl
# ✅ Convertida mtransferencias_emitidas_lag1 → mtransferencias_emitidas_lag1_pctl
# ✅ Convertida cextraccion_autoservicio_lag1 → cextraccion_autoservicio_lag1_pctl
# ✅ Convertida mextraccion_autoservicio_lag1 → mextraccion_autoservicio_lag1_pctl
# ✅ Convertida ccheques_depositados_lag1 → ccheques_depositados_lag1_pctl
# ✅ Convertida mcheques_depositados_lag1 → mcheques_depositados_lag1_pctl
# ✅ Convertida ccheques_emitidos_lag1 → ccheques_emitidos_lag1_pctl
# ✅ Convertida mcheques_emitidos_lag1 → mcheques_emitidos_lag1_pctl
# ✅ Convertida ccheques_depositados_rechazados_lag1 → ccheques_depositados_rechazados_lag1_pctl
# ✅ Convertida mcheques_depositados_rechazados_lag1 → mcheques_depositados_rechazados_lag1_pctl
# ✅ Convertida ccheques_emitidos_rechazados_lag1 → ccheques_emitidos_rechazados_lag1_pctl
# ✅ Convertida mcheques_emitidos_rechazados_lag1 → mcheques_emitidos_rechazados_lag1_pctl
# ✅ Convertida tcallcenter_lag1 → tcallcenter_lag1_pctl
# ✅ Convertida ccallcenter_transacciones_lag1 → ccallcenter_transacciones_lag1_pctl
# ✅ Convertida thomebanking_lag1 → thomebanking_lag1_pctl
# ✅ Convertida chomebanking_transacciones_lag1 → chomebanking_transacciones_lag1_pctl
# ✅ Convertida ccajas_transacciones_lag1 → ccajas_transacciones_lag1_pctl
# ✅ Convertida ccajas_consultas_lag1 → ccajas_consultas_lag1_pctl
# ✅ Convertida ccajas_depositos_lag1 → ccajas_depositos_lag1_pctl
# ✅ Convertida ccajas_extracciones_lag1 → ccajas_extracciones_lag1_pctl
# ✅ Convertida ccajas_otras_lag1 → ccajas_otras_lag1_pctl
# ✅ Convertida catm_trx_lag1 → catm_trx_lag1_pctl
# ✅ Convertida matm_lag1 → matm_lag1_pctl
# ✅ Convertida catm_trx_other_lag1 → catm_trx_other_lag1_pctl
# ✅ Convertida matm_other_lag1 → matm_other_lag1_pctl
# ✅ Convertida ctrx_quarter_lag1 → ctrx_quarter_lag1_pctl
# ✅ Convertida Master_delinquency_lag1 → Master_delinquency_lag1_pctl
# ✅ Convertida Master_status_lag1 → Master_status_lag1_pctl
# ✅ Convertida Master_mfinanciacion_limite_lag1 → Master_mfinanciacion_limite_lag1_pctl
# ✅ Convertida Master_Fvencimiento_lag1 → Master_Fvencimiento_lag1_pctl
# ✅ Convertida Master_Finiciomora_lag1 → Master_Finiciomora_lag1_pctl
# ✅ Convertida Master_msaldototal_lag1 → Master_msaldototal_lag1_pctl
# ✅ Convertida Master_msaldopesos_lag1 → Master_msaldopesos_lag1_pctl
# ✅ Convertida Master_msaldodolares_lag1 → Master_msaldodolares_lag1_pctl
# ✅ Convertida Master_mconsumospesos_lag1 → Master_mconsumospesos_lag1_pctl
# ✅ Convertida Master_mconsumosdolares_lag1 → Master_mconsumosdolares_lag1_pctl
# ✅ Convertida Master_mlimitecompra_lag1 → Master_mlimitecompra_lag1_pctl
# ✅ Convertida Master_madelantopesos_lag1 → Master_madelantopesos_lag1_pctl
# ✅ Convertida Master_madelantodolares_lag1 → Master_madelantodolares_lag1_pctl
# ✅ Convertida Master_fultimo_cierre_lag1 → Master_fultimo_cierre_lag1_pctl
# ✅ Convertida Master_mpagado_lag1 → Master_mpagado_lag1_pctl
# ✅ Convertida Master_mpagospesos_lag1 → Master_mpagospesos_lag1_pctl
# ✅ Convertida Master_mpagosdolares_lag1 → Master_mpagosdolares_lag1_pctl
# ✅ Convertida Master_fechaalta_lag1 → Master_fechaalta_lag1_pctl
# ✅ Convertida Master_mconsumototal_lag1 → Master_mconsumototal_lag1_pctl
# ✅ Convertida Master_cconsumos_lag1 → Master_cconsumos_lag1_pctl
# ✅ Convertida Master_cadelantosefectivo_lag1 → Master_cadelantosefectivo_lag1_pctl
# ✅ Convertida Master_mpagominimo_lag1 → Master_mpagominimo_lag1_pctl
# ✅ Convertida Visa_delinquency_lag1 → Visa_delinquency_lag1_pctl
# ✅ Convertida Visa_status_lag1 → Visa_status_lag1_pctl
# ✅ Convertida Visa_mfinanciacion_limite_lag1 → Visa_mfinanciacion_limite_lag1_pctl
# ✅ Convertida Visa_Fvencimiento_lag1 → Visa_Fvencimiento_lag1_pctl
# ✅ Convertida Visa_Finiciomora_lag1 → Visa_Finiciomora_lag1_pctl
# ✅ Convertida Visa_msaldototal_lag1 → Visa_msaldototal_lag1_pctl
# ✅ Convertida Visa_msaldopesos_lag1 → Visa_msaldopesos_lag1_pctl
# ✅ Convertida Visa_msaldodolares_lag1 → Visa_msaldodolares_lag1_pctl
# ✅ Convertida Visa_mconsumospesos_lag1 → Visa_mconsumospesos_lag1_pctl
# ✅ Convertida Visa_mconsumosdolares_lag1 → Visa_mconsumosdolares_lag1_pctl
# ✅ Convertida Visa_mlimitecompra_lag1 → Visa_mlimitecompra_lag1_pctl
# ✅ Convertida Visa_madelantopesos_lag1 → Visa_madelantopesos_lag1_pctl
# ✅ Convertida Visa_madelantodolares_lag1 → Visa_madelantodolares_lag1_pctl
# ✅ Convertida Visa_fultimo_cierre_lag1 → Visa_fultimo_cierre_lag1_pctl
# ✅ Convertida Visa_mpagado_lag1 → Visa_mpagado_lag1_pctl
# ✅ Convertida Visa_mpagospesos_lag1 → Visa_mpagospesos_lag1_pctl
# ✅ Convertida Visa_mpagosdolares_lag1 → Visa_mpagosdolares_lag1_pctl
# ✅ Convertida Visa_fechaalta_lag1 → Visa_fechaalta_lag1_pctl
# ✅ Convertida Visa_mconsumototal_lag1 → Visa_mconsumototal_lag1_pctl
# ✅ Convertida Visa_cconsumos_lag1 → Visa_cconsumos_lag1_pctl
# ✅ Convertida Visa_cadelantosefectivo_lag1 → Visa_cadelantosefectivo_lag1_pctl
# ✅ Convertida Visa_mpagominimo_lag1 → Visa_mpagominimo_lag1_pctl
# ✅ Convertida periodo0_lag1 → periodo0_lag1_pctl
# ✅ Convertida active_quarter_lag2 → active_quarter_lag2_pctl
# ✅ Convertida cliente_vip_lag2 → cliente_vip_lag2_pctl
# ✅ Convertida internet_lag2 → internet_lag2_pctl
# ✅ Convertida cliente_edad_lag2 → cliente_edad_lag2_pctl
# ✅ Convertida cliente_antiguedad_lag2 → cliente_antiguedad_lag2_pctl
# ✅ Convertida mrentabilidad_lag2 → mrentabilidad_lag2_pctl
# ✅ Convertida mrentabilidad_annual_lag2 → mrentabilidad_annual_lag2_pctl
# ✅ Convertida mcomisiones_lag2 → mcomisiones_lag2_pctl
# ✅ Convertida mactivos_margen_lag2 → mactivos_margen_lag2_pctl
# ✅ Convertida mpasivos_margen_lag2 → mpasivos_margen_lag2_pctl
# ✅ Convertida cproductos_lag2 → cproductos_lag2_pctl
# ✅ Convertida tcuentas_lag2 → tcuentas_lag2_pctl
# ✅ Convertida ccuenta_corriente_lag2 → ccuenta_corriente_lag2_pctl
# ✅ Convertida mcuenta_corriente_adicional_lag2 → mcuenta_corriente_adicional_lag2_pctl
# ✅ Convertida mcuenta_corriente_lag2 → mcuenta_corriente_lag2_pctl
# ✅ Convertida ccaja_ahorro_lag2 → ccaja_ahorro_lag2_pctl
# ✅ Convertida mcaja_ahorro_lag2 → mcaja_ahorro_lag2_pctl
# ✅ Convertida mcaja_ahorro_adicional_lag2 → mcaja_ahorro_adicional_lag2_pctl
# ✅ Convertida mcaja_ahorro_dolares_lag2 → mcaja_ahorro_dolares_lag2_pctl
# ✅ Convertida cdescubierto_preacordado_lag2 → cdescubierto_preacordado_lag2_pctl
# ✅ Convertida mcuentas_saldo_lag2 → mcuentas_saldo_lag2_pctl
# ✅ Convertida ctarjeta_debito_lag2 → ctarjeta_debito_lag2_pctl
# ✅ Convertida ctarjeta_debito_transacciones_lag2 → ctarjeta_debito_transacciones_lag2_pctl
# ✅ Convertida mautoservicio_lag2 → mautoservicio_lag2_pctl
# ✅ Convertida ctarjeta_visa_lag2 → ctarjeta_visa_lag2_pctl
# ✅ Convertida ctarjeta_visa_transacciones_lag2 → ctarjeta_visa_transacciones_lag2_pctl
# ✅ Convertida mtarjeta_visa_consumo_lag2 → mtarjeta_visa_consumo_lag2_pctl
# ✅ Convertida ctarjeta_master_lag2 → ctarjeta_master_lag2_pctl
# ✅ Convertida ctarjeta_master_transacciones_lag2 → ctarjeta_master_transacciones_lag2_pctl
# ✅ Convertida mtarjeta_master_consumo_lag2 → mtarjeta_master_consumo_lag2_pctl
# ✅ Convertida cprestamos_personales_lag2 → cprestamos_personales_lag2_pctl
# ✅ Convertida mprestamos_personales_lag2 → mprestamos_personales_lag2_pctl
# ✅ Convertida cprestamos_prendarios_lag2 → cprestamos_prendarios_lag2_pctl
# ✅ Convertida mprestamos_prendarios_lag2 → mprestamos_prendarios_lag2_pctl
# ✅ Convertida cprestamos_hipotecarios_lag2 → cprestamos_hipotecarios_lag2_pctl
# ✅ Convertida mprestamos_hipotecarios_lag2 → mprestamos_hipotecarios_lag2_pctl
# ✅ Convertida cplazo_fijo_lag2 → cplazo_fijo_lag2_pctl
# ✅ Convertida mplazo_fijo_dolares_lag2 → mplazo_fijo_dolares_lag2_pctl
# ✅ Convertida mplazo_fijo_pesos_lag2 → mplazo_fijo_pesos_lag2_pctl
# ✅ Convertida cinversion1_lag2 → cinversion1_lag2_pctl
# ✅ Convertida minversion1_pesos_lag2 → minversion1_pesos_lag2_pctl
# ✅ Convertida minversion1_dolares_lag2 → minversion1_dolares_lag2_pctl
# ✅ Convertida cinversion2_lag2 → cinversion2_lag2_pctl
# ✅ Convertida minversion2_lag2 → minversion2_lag2_pctl
# ✅ Convertida cseguro_vida_lag2 → cseguro_vida_lag2_pctl
# ✅ Convertida cseguro_auto_lag2 → cseguro_auto_lag2_pctl
# ✅ Convertida cseguro_vivienda_lag2 → cseguro_vivienda_lag2_pctl
# ✅ Convertida cseguro_accidentes_personales_lag2 → cseguro_accidentes_personales_lag2_pctl
# ✅ Convertida ccaja_seguridad_lag2 → ccaja_seguridad_lag2_pctl
# ✅ Convertida cpayroll_trx_lag2 → cpayroll_trx_lag2_pctl
# ✅ Convertida mpayroll_lag2 → mpayroll_lag2_pctl
# ✅ Convertida mpayroll2_lag2 → mpayroll2_lag2_pctl
# ✅ Convertida cpayroll2_trx_lag2 → cpayroll2_trx_lag2_pctl
# ✅ Convertida ccuenta_debitos_automaticos_lag2 → ccuenta_debitos_automaticos_lag2_pctl
# ✅ Convertida mcuenta_debitos_automaticos_lag2 → mcuenta_debitos_automaticos_lag2_pctl
# ✅ Convertida ctarjeta_visa_debitos_automaticos_lag2 → ctarjeta_visa_debitos_automaticos_lag2_pctl
# ✅ Convertida mttarjeta_visa_debitos_automaticos_lag2 → mttarjeta_visa_debitos_automaticos_lag2_pctl
# ✅ Convertida ctarjeta_master_debitos_automaticos_lag2 → ctarjeta_master_debitos_automaticos_lag2_pctl
# ✅ Convertida mttarjeta_master_debitos_automaticos_lag2 → mttarjeta_master_debitos_automaticos_lag2_pctl
# ✅ Convertida cpagodeservicios_lag2 → cpagodeservicios_lag2_pctl
# ✅ Convertida mpagodeservicios_lag2 → mpagodeservicios_lag2_pctl
# ✅ Convertida cpagomiscuentas_lag2 → cpagomiscuentas_lag2_pctl
# ✅ Convertida mpagomiscuentas_lag2 → mpagomiscuentas_lag2_pctl
# ✅ Convertida ccajeros_propios_descuentos_lag2 → ccajeros_propios_descuentos_lag2_pctl
# ✅ Convertida mcajeros_propios_descuentos_lag2 → mcajeros_propios_descuentos_lag2_pctl
# ✅ Convertida ctarjeta_visa_descuentos_lag2 → ctarjeta_visa_descuentos_lag2_pctl
# ✅ Convertida mtarjeta_visa_descuentos_lag2 → mtarjeta_visa_descuentos_lag2_pctl
# ✅ Convertida ctarjeta_master_descuentos_lag2 → ctarjeta_master_descuentos_lag2_pctl
# ✅ Convertida mtarjeta_master_descuentos_lag2 → mtarjeta_master_descuentos_lag2_pctl
# ✅ Convertida ccomisiones_mantenimiento_lag2 → ccomisiones_mantenimiento_lag2_pctl
# ✅ Convertida mcomisiones_mantenimiento_lag2 → mcomisiones_mantenimiento_lag2_pctl
# ✅ Convertida ccomisiones_otras_lag2 → ccomisiones_otras_lag2_pctl
# ✅ Convertida mcomisiones_otras_lag2 → mcomisiones_otras_lag2_pctl
# ✅ Convertida cforex_lag2 → cforex_lag2_pctl
# ✅ Convertida cforex_buy_lag2 → cforex_buy_lag2_pctl
# ✅ Convertida mforex_buy_lag2 → mforex_buy_lag2_pctl
# ✅ Convertida cforex_sell_lag2 → cforex_sell_lag2_pctl
# ✅ Convertida mforex_sell_lag2 → mforex_sell_lag2_pctl
# ✅ Convertida ctransferencias_recibidas_lag2 → ctransferencias_recibidas_lag2_pctl
# ✅ Convertida mtransferencias_recibidas_lag2 → mtransferencias_recibidas_lag2_pctl
# ✅ Convertida ctransferencias_emitidas_lag2 → ctransferencias_emitidas_lag2_pctl
# ✅ Convertida mtransferencias_emitidas_lag2 → mtransferencias_emitidas_lag2_pctl
# ✅ Convertida cextraccion_autoservicio_lag2 → cextraccion_autoservicio_lag2_pctl
# ✅ Convertida mextraccion_autoservicio_lag2 → mextraccion_autoservicio_lag2_pctl
# ✅ Convertida ccheques_depositados_lag2 → ccheques_depositados_lag2_pctl
# ✅ Convertida mcheques_depositados_lag2 → mcheques_depositados_lag2_pctl
# ✅ Convertida ccheques_emitidos_lag2 → ccheques_emitidos_lag2_pctl
# ✅ Convertida mcheques_emitidos_lag2 → mcheques_emitidos_lag2_pctl
# ✅ Convertida ccheques_depositados_rechazados_lag2 → ccheques_depositados_rechazados_lag2_pctl
# ✅ Convertida mcheques_depositados_rechazados_lag2 → mcheques_depositados_rechazados_lag2_pctl
# ✅ Convertida ccheques_emitidos_rechazados_lag2 → ccheques_emitidos_rechazados_lag2_pctl
# ✅ Convertida mcheques_emitidos_rechazados_lag2 → mcheques_emitidos_rechazados_lag2_pctl
# ✅ Convertida tcallcenter_lag2 → tcallcenter_lag2_pctl
# ✅ Convertida ccallcenter_transacciones_lag2 → ccallcenter_transacciones_lag2_pctl
# ✅ Convertida thomebanking_lag2 → thomebanking_lag2_pctl
# ✅ Convertida chomebanking_transacciones_lag2 → chomebanking_transacciones_lag2_pctl
# ✅ Convertida ccajas_transacciones_lag2 → ccajas_transacciones_lag2_pctl
# ✅ Convertida ccajas_consultas_lag2 → ccajas_consultas_lag2_pctl
# ✅ Convertida ccajas_depositos_lag2 → ccajas_depositos_lag2_pctl
# ✅ Convertida ccajas_extracciones_lag2 → ccajas_extracciones_lag2_pctl
# ✅ Convertida ccajas_otras_lag2 → ccajas_otras_lag2_pctl
# ✅ Convertida catm_trx_lag2 → catm_trx_lag2_pctl
# ✅ Convertida matm_lag2 → matm_lag2_pctl
# ✅ Convertida catm_trx_other_lag2 → catm_trx_other_lag2_pctl
# ✅ Convertida matm_other_lag2 → matm_other_lag2_pctl
# ✅ Convertida ctrx_quarter_lag2 → ctrx_quarter_lag2_pctl
# ✅ Convertida Master_delinquency_lag2 → Master_delinquency_lag2_pctl
# ✅ Convertida Master_status_lag2 → Master_status_lag2_pctl
# ✅ Convertida Master_mfinanciacion_limite_lag2 → Master_mfinanciacion_limite_lag2_pctl
# ✅ Convertida Master_Fvencimiento_lag2 → Master_Fvencimiento_lag2_pctl
# ✅ Convertida Master_Finiciomora_lag2 → Master_Finiciomora_lag2_pctl
# ✅ Convertida Master_msaldototal_lag2 → Master_msaldototal_lag2_pctl
# ✅ Convertida Master_msaldopesos_lag2 → Master_msaldopesos_lag2_pctl
# ✅ Convertida Master_msaldodolares_lag2 → Master_msaldodolares_lag2_pctl
# ✅ Convertida Master_mconsumospesos_lag2 → Master_mconsumospesos_lag2_pctl
# ✅ Convertida Master_mconsumosdolares_lag2 → Master_mconsumosdolares_lag2_pctl
# ✅ Convertida Master_mlimitecompra_lag2 → Master_mlimitecompra_lag2_pctl
# ✅ Convertida Master_madelantopesos_lag2 → Master_madelantopesos_lag2_pctl
# ✅ Convertida Master_madelantodolares_lag2 → Master_madelantodolares_lag2_pctl
# ✅ Convertida Master_fultimo_cierre_lag2 → Master_fultimo_cierre_lag2_pctl
# ✅ Convertida Master_mpagado_lag2 → Master_mpagado_lag2_pctl
# ✅ Convertida Master_mpagospesos_lag2 → Master_mpagospesos_lag2_pctl
# ✅ Convertida Master_mpagosdolares_lag2 → Master_mpagosdolares_lag2_pctl
# ✅ Convertida Master_fechaalta_lag2 → Master_fechaalta_lag2_pctl
# ✅ Convertida Master_mconsumototal_lag2 → Master_mconsumototal_lag2_pctl
# ✅ Convertida Master_cconsumos_lag2 → Master_cconsumos_lag2_pctl
# ✅ Convertida Master_cadelantosefectivo_lag2 → Master_cadelantosefectivo_lag2_pctl
# ✅ Convertida Master_mpagominimo_lag2 → Master_mpagominimo_lag2_pctl
# ✅ Convertida Visa_delinquency_lag2 → Visa_delinquency_lag2_pctl
# ✅ Convertida Visa_status_lag2 → Visa_status_lag2_pctl
# ✅ Convertida Visa_mfinanciacion_limite_lag2 → Visa_mfinanciacion_limite_lag2_pctl
# ✅ Convertida Visa_Fvencimiento_lag2 → Visa_Fvencimiento_lag2_pctl
# ✅ Convertida Visa_Finiciomora_lag2 → Visa_Finiciomora_lag2_pctl
# ✅ Convertida Visa_msaldototal_lag2 → Visa_msaldototal_lag2_pctl
# ✅ Convertida Visa_msaldopesos_lag2 → Visa_msaldopesos_lag2_pctl
# ✅ Convertida Visa_msaldodolares_lag2 → Visa_msaldodolares_lag2_pctl
# ✅ Convertida Visa_mconsumospesos_lag2 → Visa_mconsumospesos_lag2_pctl
# ✅ Convertida Visa_mconsumosdolares_lag2 → Visa_mconsumosdolares_lag2_pctl
# ✅ Convertida Visa_mlimitecompra_lag2 → Visa_mlimitecompra_lag2_pctl
# ✅ Convertida Visa_madelantopesos_lag2 → Visa_madelantopesos_lag2_pctl
# ✅ Convertida Visa_madelantodolares_lag2 → Visa_madelantodolares_lag2_pctl
# ✅ Convertida Visa_fultimo_cierre_lag2 → Visa_fultimo_cierre_lag2_pctl
# ✅ Convertida Visa_mpagado_lag2 → Visa_mpagado_lag2_pctl
# ✅ Convertida Visa_mpagospesos_lag2 → Visa_mpagospesos_lag2_pctl
# ✅ Convertida Visa_mpagosdolares_lag2 → Visa_mpagosdolares_lag2_pctl
# ✅ Convertida Visa_fechaalta_lag2 → Visa_fechaalta_lag2_pctl
# ✅ Convertida Visa_mconsumototal_lag2 → Visa_mconsumototal_lag2_pctl
# ✅ Convertida Visa_cconsumos_lag2 → Visa_cconsumos_lag2_pctl
# ✅ Convertida Visa_cadelantosefectivo_lag2 → Visa_cadelantosefectivo_lag2_pctl
# ✅ Convertida Visa_mpagominimo_lag2 → Visa_mpagominimo_lag2_pctl
# ✅ Convertida periodo0_lag2 → periodo0_lag2_pctl
# ✅ Convertida active_quarter_dlag1 → active_quarter_dlag1_pctl
# ✅ Convertida cliente_vip_dlag1 → cliente_vip_dlag1_pctl
# ✅ Convertida internet_dlag1 → internet_dlag1_pctl
# ✅ Convertida cliente_edad_dlag1 → cliente_edad_dlag1_pctl
# ✅ Convertida cliente_antiguedad_dlag1 → cliente_antiguedad_dlag1_pctl
# ✅ Convertida mrentabilidad_dlag1 → mrentabilidad_dlag1_pctl
# ✅ Convertida mrentabilidad_annual_dlag1 → mrentabilidad_annual_dlag1_pctl
# ✅ Convertida mcomisiones_dlag1 → mcomisiones_dlag1_pctl
# ✅ Convertida mactivos_margen_dlag1 → mactivos_margen_dlag1_pctl
# ✅ Convertida mpasivos_margen_dlag1 → mpasivos_margen_dlag1_pctl
# ✅ Convertida cproductos_dlag1 → cproductos_dlag1_pctl
# ✅ Convertida tcuentas_dlag1 → tcuentas_dlag1_pctl
# ✅ Convertida ccuenta_corriente_dlag1 → ccuenta_corriente_dlag1_pctl
# ✅ Convertida mcuenta_corriente_adicional_dlag1 → mcuenta_corriente_adicional_dlag1_pctl
# ✅ Convertida mcuenta_corriente_dlag1 → mcuenta_corriente_dlag1_pctl
# ✅ Convertida ccaja_ahorro_dlag1 → ccaja_ahorro_dlag1_pctl
# ✅ Convertida mcaja_ahorro_dlag1 → mcaja_ahorro_dlag1_pctl
# ✅ Convertida mcaja_ahorro_adicional_dlag1 → mcaja_ahorro_adicional_dlag1_pctl
# ✅ Convertida mcaja_ahorro_dolares_dlag1 → mcaja_ahorro_dolares_dlag1_pctl
# ✅ Convertida cdescubierto_preacordado_dlag1 → cdescubierto_preacordado_dlag1_pctl
# ✅ Convertida mcuentas_saldo_dlag1 → mcuentas_saldo_dlag1_pctl
# ✅ Convertida ctarjeta_debito_dlag1 → ctarjeta_debito_dlag1_pctl
# ✅ Convertida ctarjeta_debito_transacciones_dlag1 → ctarjeta_debito_transacciones_dlag1_pctl
# ✅ Convertida mautoservicio_dlag1 → mautoservicio_dlag1_pctl
# ✅ Convertida ctarjeta_visa_dlag1 → ctarjeta_visa_dlag1_pctl
# ✅ Convertida ctarjeta_visa_transacciones_dlag1 → ctarjeta_visa_transacciones_dlag1_pctl
# ✅ Convertida mtarjeta_visa_consumo_dlag1 → mtarjeta_visa_consumo_dlag1_pctl
# ✅ Convertida ctarjeta_master_dlag1 → ctarjeta_master_dlag1_pctl
# ✅ Convertida ctarjeta_master_transacciones_dlag1 → ctarjeta_master_transacciones_dlag1_pctl
# ✅ Convertida mtarjeta_master_consumo_dlag1 → mtarjeta_master_consumo_dlag1_pctl
# ✅ Convertida cprestamos_personales_dlag1 → cprestamos_personales_dlag1_pctl
# ✅ Convertida mprestamos_personales_dlag1 → mprestamos_personales_dlag1_pctl
# ✅ Convertida cprestamos_prendarios_dlag1 → cprestamos_prendarios_dlag1_pctl
# ✅ Convertida mprestamos_prendarios_dlag1 → mprestamos_prendarios_dlag1_pctl
# ✅ Convertida cprestamos_hipotecarios_dlag1 → cprestamos_hipotecarios_dlag1_pctl
# ✅ Convertida mprestamos_hipotecarios_dlag1 → mprestamos_hipotecarios_dlag1_pctl
# ✅ Convertida cplazo_fijo_dlag1 → cplazo_fijo_dlag1_pctl
# ✅ Convertida mplazo_fijo_dolares_dlag1 → mplazo_fijo_dolares_dlag1_pctl
# ✅ Convertida mplazo_fijo_pesos_dlag1 → mplazo_fijo_pesos_dlag1_pctl
# ✅ Convertida cinversion1_dlag1 → cinversion1_dlag1_pctl
# ✅ Convertida minversion1_pesos_dlag1 → minversion1_pesos_dlag1_pctl
# ✅ Convertida minversion1_dolares_dlag1 → minversion1_dolares_dlag1_pctl
# ✅ Convertida cinversion2_dlag1 → cinversion2_dlag1_pctl
# ✅ Convertida minversion2_dlag1 → minversion2_dlag1_pctl
# ✅ Convertida cseguro_vida_dlag1 → cseguro_vida_dlag1_pctl
# ✅ Convertida cseguro_auto_dlag1 → cseguro_auto_dlag1_pctl
# ✅ Convertida cseguro_vivienda_dlag1 → cseguro_vivienda_dlag1_pctl
# ✅ Convertida cseguro_accidentes_personales_dlag1 → cseguro_accidentes_personales_dlag1_pctl
# ✅ Convertida ccaja_seguridad_dlag1 → ccaja_seguridad_dlag1_pctl
# ✅ Convertida cpayroll_trx_dlag1 → cpayroll_trx_dlag1_pctl
# ✅ Convertida mpayroll_dlag1 → mpayroll_dlag1_pctl
# ✅ Convertida mpayroll2_dlag1 → mpayroll2_dlag1_pctl
# ✅ Convertida cpayroll2_trx_dlag1 → cpayroll2_trx_dlag1_pctl
# ✅ Convertida ccuenta_debitos_automaticos_dlag1 → ccuenta_debitos_automaticos_dlag1_pctl
# ✅ Convertida mcuenta_debitos_automaticos_dlag1 → mcuenta_debitos_automaticos_dlag1_pctl
# ✅ Convertida ctarjeta_visa_debitos_automaticos_dlag1 → ctarjeta_visa_debitos_automaticos_dlag1_pctl
# ✅ Convertida mttarjeta_visa_debitos_automaticos_dlag1 → mttarjeta_visa_debitos_automaticos_dlag1_pctl
# ✅ Convertida ctarjeta_master_debitos_automaticos_dlag1 → ctarjeta_master_debitos_automaticos_dlag1_pctl
# ✅ Convertida mttarjeta_master_debitos_automaticos_dlag1 → mttarjeta_master_debitos_automaticos_dlag1_pctl
# ✅ Convertida cpagodeservicios_dlag1 → cpagodeservicios_dlag1_pctl
# ✅ Convertida mpagodeservicios_dlag1 → mpagodeservicios_dlag1_pctl
# ✅ Convertida cpagomiscuentas_dlag1 → cpagomiscuentas_dlag1_pctl
# ✅ Convertida mpagomiscuentas_dlag1 → mpagomiscuentas_dlag1_pctl
# ✅ Convertida ccajeros_propios_descuentos_dlag1 → ccajeros_propios_descuentos_dlag1_pctl
# ✅ Convertida mcajeros_propios_descuentos_dlag1 → mcajeros_propios_descuentos_dlag1_pctl
# ✅ Convertida ctarjeta_visa_descuentos_dlag1 → ctarjeta_visa_descuentos_dlag1_pctl
# ✅ Convertida mtarjeta_visa_descuentos_dlag1 → mtarjeta_visa_descuentos_dlag1_pctl
# ✅ Convertida ctarjeta_master_descuentos_dlag1 → ctarjeta_master_descuentos_dlag1_pctl
# ✅ Convertida mtarjeta_master_descuentos_dlag1 → mtarjeta_master_descuentos_dlag1_pctl
# ✅ Convertida ccomisiones_mantenimiento_dlag1 → ccomisiones_mantenimiento_dlag1_pctl
# ✅ Convertida mcomisiones_mantenimiento_dlag1 → mcomisiones_mantenimiento_dlag1_pctl
# ✅ Convertida ccomisiones_otras_dlag1 → ccomisiones_otras_dlag1_pctl
# ✅ Convertida mcomisiones_otras_dlag1 → mcomisiones_otras_dlag1_pctl
# ✅ Convertida cforex_dlag1 → cforex_dlag1_pctl
# ✅ Convertida cforex_buy_dlag1 → cforex_buy_dlag1_pctl
# ✅ Convertida mforex_buy_dlag1 → mforex_buy_dlag1_pctl
# ✅ Convertida cforex_sell_dlag1 → cforex_sell_dlag1_pctl
# ✅ Convertida mforex_sell_dlag1 → mforex_sell_dlag1_pctl
# ✅ Convertida ctransferencias_recibidas_dlag1 → ctransferencias_recibidas_dlag1_pctl
# ✅ Convertida mtransferencias_recibidas_dlag1 → mtransferencias_recibidas_dlag1_pctl
# ✅ Convertida ctransferencias_emitidas_dlag1 → ctransferencias_emitidas_dlag1_pctl
# ✅ Convertida mtransferencias_emitidas_dlag1 → mtransferencias_emitidas_dlag1_pctl
# ✅ Convertida cextraccion_autoservicio_dlag1 → cextraccion_autoservicio_dlag1_pctl
# ✅ Convertida mextraccion_autoservicio_dlag1 → mextraccion_autoservicio_dlag1_pctl
# ✅ Convertida ccheques_depositados_dlag1 → ccheques_depositados_dlag1_pctl
# ✅ Convertida mcheques_depositados_dlag1 → mcheques_depositados_dlag1_pctl
# ✅ Convertida ccheques_emitidos_dlag1 → ccheques_emitidos_dlag1_pctl
# ✅ Convertida mcheques_emitidos_dlag1 → mcheques_emitidos_dlag1_pctl
# ✅ Convertida ccheques_depositados_rechazados_dlag1 → ccheques_depositados_rechazados_dlag1_pctl
# ✅ Convertida mcheques_depositados_rechazados_dlag1 → mcheques_depositados_rechazados_dlag1_pctl
# ✅ Convertida ccheques_emitidos_rechazados_dlag1 → ccheques_emitidos_rechazados_dlag1_pctl
# ✅ Convertida mcheques_emitidos_rechazados_dlag1 → mcheques_emitidos_rechazados_dlag1_pctl
# ✅ Convertida tcallcenter_dlag1 → tcallcenter_dlag1_pctl
# ✅ Convertida ccallcenter_transacciones_dlag1 → ccallcenter_transacciones_dlag1_pctl
# ✅ Convertida thomebanking_dlag1 → thomebanking_dlag1_pctl
# ✅ Convertida chomebanking_transacciones_dlag1 → chomebanking_transacciones_dlag1_pctl
# ✅ Convertida ccajas_transacciones_dlag1 → ccajas_transacciones_dlag1_pctl
# ✅ Convertida ccajas_consultas_dlag1 → ccajas_consultas_dlag1_pctl
# ✅ Convertida ccajas_depositos_dlag1 → ccajas_depositos_dlag1_pctl
# ✅ Convertida ccajas_extracciones_dlag1 → ccajas_extracciones_dlag1_pctl
# ✅ Convertida ccajas_otras_dlag1 → ccajas_otras_dlag1_pctl
# ✅ Convertida catm_trx_dlag1 → catm_trx_dlag1_pctl
# ✅ Convertida matm_dlag1 → matm_dlag1_pctl
# ✅ Convertida catm_trx_other_dlag1 → catm_trx_other_dlag1_pctl
# ✅ Convertida matm_other_dlag1 → matm_other_dlag1_pctl
# ✅ Convertida ctrx_quarter_dlag1 → ctrx_quarter_dlag1_pctl
# ✅ Convertida Master_delinquency_dlag1 → Master_delinquency_dlag1_pctl
# ✅ Convertida Master_status_dlag1 → Master_status_dlag1_pctl
# ✅ Convertida Master_mfinanciacion_limite_dlag1 → Master_mfinanciacion_limite_dlag1_pctl
# ✅ Convertida Master_Fvencimiento_dlag1 → Master_Fvencimiento_dlag1_pctl
# ✅ Convertida Master_Finiciomora_dlag1 → Master_Finiciomora_dlag1_pctl
# ✅ Convertida Master_msaldototal_dlag1 → Master_msaldototal_dlag1_pctl
# ✅ Convertida Master_msaldopesos_dlag1 → Master_msaldopesos_dlag1_pctl
# ✅ Convertida Master_msaldodolares_dlag1 → Master_msaldodolares_dlag1_pctl
# ✅ Convertida Master_mconsumospesos_dlag1 → Master_mconsumospesos_dlag1_pctl
# ✅ Convertida Master_mconsumosdolares_dlag1 → Master_mconsumosdolares_dlag1_pctl
# ✅ Convertida Master_mlimitecompra_dlag1 → Master_mlimitecompra_dlag1_pctl
# ✅ Convertida Master_madelantopesos_dlag1 → Master_madelantopesos_dlag1_pctl
# ✅ Convertida Master_madelantodolares_dlag1 → Master_madelantodolares_dlag1_pctl
# ✅ Convertida Master_fultimo_cierre_dlag1 → Master_fultimo_cierre_dlag1_pctl
# ✅ Convertida Master_mpagado_dlag1 → Master_mpagado_dlag1_pctl
# ✅ Convertida Master_mpagospesos_dlag1 → Master_mpagospesos_dlag1_pctl
# ✅ Convertida Master_mpagosdolares_dlag1 → Master_mpagosdolares_dlag1_pctl
# ✅ Convertida Master_fechaalta_dlag1 → Master_fechaalta_dlag1_pctl
# ✅ Convertida Master_mconsumototal_dlag1 → Master_mconsumototal_dlag1_pctl
# ✅ Convertida Master_cconsumos_dlag1 → Master_cconsumos_dlag1_pctl
# ✅ Convertida Master_cadelantosefectivo_dlag1 → Master_cadelantosefectivo_dlag1_pctl
# ✅ Convertida Master_mpagominimo_dlag1 → Master_mpagominimo_dlag1_pctl
# ✅ Convertida Visa_delinquency_dlag1 → Visa_delinquency_dlag1_pctl
# ✅ Convertida Visa_status_dlag1 → Visa_status_dlag1_pctl
# ✅ Convertida Visa_mfinanciacion_limite_dlag1 → Visa_mfinanciacion_limite_dlag1_pctl
# ✅ Convertida Visa_Fvencimiento_dlag1 → Visa_Fvencimiento_dlag1_pctl
# ✅ Convertida Visa_Finiciomora_dlag1 → Visa_Finiciomora_dlag1_pctl
# ✅ Convertida Visa_msaldototal_dlag1 → Visa_msaldototal_dlag1_pctl
# ✅ Convertida Visa_msaldopesos_dlag1 → Visa_msaldopesos_dlag1_pctl
# ✅ Convertida Visa_msaldodolares_dlag1 → Visa_msaldodolares_dlag1_pctl
# ✅ Convertida Visa_mconsumospesos_dlag1 → Visa_mconsumospesos_dlag1_pctl
# ✅ Convertida Visa_mconsumosdolares_dlag1 → Visa_mconsumosdolares_dlag1_pctl
# ✅ Convertida Visa_mlimitecompra_dlag1 → Visa_mlimitecompra_dlag1_pctl
# ✅ Convertida Visa_madelantopesos_dlag1 → Visa_madelantopesos_dlag1_pctl
# ✅ Convertida Visa_madelantodolares_dlag1 → Visa_madelantodolares_dlag1_pctl
# ✅ Convertida Visa_fultimo_cierre_dlag1 → Visa_fultimo_cierre_dlag1_pctl
# ✅ Convertida Visa_mpagado_dlag1 → Visa_mpagado_dlag1_pctl
# ✅ Convertida Visa_mpagospesos_dlag1 → Visa_mpagospesos_dlag1_pctl
# ✅ Convertida Visa_mpagosdolares_dlag1 → Visa_mpagosdolares_dlag1_pctl
# ✅ Convertida Visa_fechaalta_dlag1 → Visa_fechaalta_dlag1_pctl
# ✅ Convertida Visa_mconsumototal_dlag1 → Visa_mconsumototal_dlag1_pctl
# ✅ Convertida Visa_cconsumos_dlag1 → Visa_cconsumos_dlag1_pctl
# ✅ Convertida Visa_cadelantosefectivo_dlag1 → Visa_cadelantosefectivo_dlag1_pctl
# ✅ Convertida Visa_mpagominimo_dlag1 → Visa_mpagominimo_dlag1_pctl
# ✅ Convertida periodo0_dlag1 → periodo0_dlag1_pctl
# ✅ Convertida active_quarter_dlag2 → active_quarter_dlag2_pctl
# ✅ Convertida cliente_vip_dlag2 → cliente_vip_dlag2_pctl
# ✅ Convertida internet_dlag2 → internet_dlag2_pctl
# ✅ Convertida cliente_edad_dlag2 → cliente_edad_dlag2_pctl
# ✅ Convertida cliente_antiguedad_dlag2 → cliente_antiguedad_dlag2_pctl
# ✅ Convertida mrentabilidad_dlag2 → mrentabilidad_dlag2_pctl
# ✅ Convertida mrentabilidad_annual_dlag2 → mrentabilidad_annual_dlag2_pctl
# ✅ Convertida mcomisiones_dlag2 → mcomisiones_dlag2_pctl
# ✅ Convertida mactivos_margen_dlag2 → mactivos_margen_dlag2_pctl
# ✅ Convertida mpasivos_margen_dlag2 → mpasivos_margen_dlag2_pctl
# ✅ Convertida cproductos_dlag2 → cproductos_dlag2_pctl
# ✅ Convertida tcuentas_dlag2 → tcuentas_dlag2_pctl
# ✅ Convertida ccuenta_corriente_dlag2 → ccuenta_corriente_dlag2_pctl
# ✅ Convertida mcuenta_corriente_adicional_dlag2 → mcuenta_corriente_adicional_dlag2_pctl
# ✅ Convertida mcuenta_corriente_dlag2 → mcuenta_corriente_dlag2_pctl
# ✅ Convertida ccaja_ahorro_dlag2 → ccaja_ahorro_dlag2_pctl
# ✅ Convertida mcaja_ahorro_dlag2 → mcaja_ahorro_dlag2_pctl
# ✅ Convertida mcaja_ahorro_adicional_dlag2 → mcaja_ahorro_adicional_dlag2_pctl
# ✅ Convertida mcaja_ahorro_dolares_dlag2 → mcaja_ahorro_dolares_dlag2_pctl
# ✅ Convertida cdescubierto_preacordado_dlag2 → cdescubierto_preacordado_dlag2_pctl
# ✅ Convertida mcuentas_saldo_dlag2 → mcuentas_saldo_dlag2_pctl
# ✅ Convertida ctarjeta_debito_dlag2 → ctarjeta_debito_dlag2_pctl
# ✅ Convertida ctarjeta_debito_transacciones_dlag2 → ctarjeta_debito_transacciones_dlag2_pctl
# ✅ Convertida mautoservicio_dlag2 → mautoservicio_dlag2_pctl
# ✅ Convertida ctarjeta_visa_dlag2 → ctarjeta_visa_dlag2_pctl
# ✅ Convertida ctarjeta_visa_transacciones_dlag2 → ctarjeta_visa_transacciones_dlag2_pctl
# ✅ Convertida mtarjeta_visa_consumo_dlag2 → mtarjeta_visa_consumo_dlag2_pctl
# ✅ Convertida ctarjeta_master_dlag2 → ctarjeta_master_dlag2_pctl
# ✅ Convertida ctarjeta_master_transacciones_dlag2 → ctarjeta_master_transacciones_dlag2_pctl
# ✅ Convertida mtarjeta_master_consumo_dlag2 → mtarjeta_master_consumo_dlag2_pctl
# ✅ Convertida cprestamos_personales_dlag2 → cprestamos_personales_dlag2_pctl
# ✅ Convertida mprestamos_personales_dlag2 → mprestamos_personales_dlag2_pctl
# ✅ Convertida cprestamos_prendarios_dlag2 → cprestamos_prendarios_dlag2_pctl
# ✅ Convertida mprestamos_prendarios_dlag2 → mprestamos_prendarios_dlag2_pctl
# ✅ Convertida cprestamos_hipotecarios_dlag2 → cprestamos_hipotecarios_dlag2_pctl
# ✅ Convertida mprestamos_hipotecarios_dlag2 → mprestamos_hipotecarios_dlag2_pctl
# ✅ Convertida cplazo_fijo_dlag2 → cplazo_fijo_dlag2_pctl
# ✅ Convertida mplazo_fijo_dolares_dlag2 → mplazo_fijo_dolares_dlag2_pctl
# ✅ Convertida mplazo_fijo_pesos_dlag2 → mplazo_fijo_pesos_dlag2_pctl
# ✅ Convertida cinversion1_dlag2 → cinversion1_dlag2_pctl
# ✅ Convertida minversion1_pesos_dlag2 → minversion1_pesos_dlag2_pctl
# ✅ Convertida minversion1_dolares_dlag2 → minversion1_dolares_dlag2_pctl
# ✅ Convertida cinversion2_dlag2 → cinversion2_dlag2_pctl
# ✅ Convertida minversion2_dlag2 → minversion2_dlag2_pctl
# ✅ Convertida cseguro_vida_dlag2 → cseguro_vida_dlag2_pctl
# ✅ Convertida cseguro_auto_dlag2 → cseguro_auto_dlag2_pctl
# ✅ Convertida cseguro_vivienda_dlag2 → cseguro_vivienda_dlag2_pctl
# ✅ Convertida cseguro_accidentes_personales_dlag2 → cseguro_accidentes_personales_dlag2_pctl
# ✅ Convertida ccaja_seguridad_dlag2 → ccaja_seguridad_dlag2_pctl
# ✅ Convertida cpayroll_trx_dlag2 → cpayroll_trx_dlag2_pctl
# ✅ Convertida mpayroll_dlag2 → mpayroll_dlag2_pctl
# ✅ Convertida mpayroll2_dlag2 → mpayroll2_dlag2_pctl
# ✅ Convertida cpayroll2_trx_dlag2 → cpayroll2_trx_dlag2_pctl
# ✅ Convertida ccuenta_debitos_automaticos_dlag2 → ccuenta_debitos_automaticos_dlag2_pctl
# ✅ Convertida mcuenta_debitos_automaticos_dlag2 → mcuenta_debitos_automaticos_dlag2_pctl
# ✅ Convertida ctarjeta_visa_debitos_automaticos_dlag2 → ctarjeta_visa_debitos_automaticos_dlag2_pctl
# ✅ Convertida mttarjeta_visa_debitos_automaticos_dlag2 → mttarjeta_visa_debitos_automaticos_dlag2_pctl
# ✅ Convertida ctarjeta_master_debitos_automaticos_dlag2 → ctarjeta_master_debitos_automaticos_dlag2_pctl
# ✅ Convertida mttarjeta_master_debitos_automaticos_dlag2 → mttarjeta_master_debitos_automaticos_dlag2_pctl
# ✅ Convertida cpagodeservicios_dlag2 → cpagodeservicios_dlag2_pctl
# ✅ Convertida mpagodeservicios_dlag2 → mpagodeservicios_dlag2_pctl
# ✅ Convertida cpagomiscuentas_dlag2 → cpagomiscuentas_dlag2_pctl
# ✅ Convertida mpagomiscuentas_dlag2 → mpagomiscuentas_dlag2_pctl
# ✅ Convertida ccajeros_propios_descuentos_dlag2 → ccajeros_propios_descuentos_dlag2_pctl
# ✅ Convertida mcajeros_propios_descuentos_dlag2 → mcajeros_propios_descuentos_dlag2_pctl
# ✅ Convertida ctarjeta_visa_descuentos_dlag2 → ctarjeta_visa_descuentos_dlag2_pctl
# ✅ Convertida mtarjeta_visa_descuentos_dlag2 → mtarjeta_visa_descuentos_dlag2_pctl
# ✅ Convertida ctarjeta_master_descuentos_dlag2 → ctarjeta_master_descuentos_dlag2_pctl
# ✅ Convertida mtarjeta_master_descuentos_dlag2 → mtarjeta_master_descuentos_dlag2_pctl
# ✅ Convertida ccomisiones_mantenimiento_dlag2 → ccomisiones_mantenimiento_dlag2_pctl
# ✅ Convertida mcomisiones_mantenimiento_dlag2 → mcomisiones_mantenimiento_dlag2_pctl
# ✅ Convertida ccomisiones_otras_dlag2 → ccomisiones_otras_dlag2_pctl
# ✅ Convertida mcomisiones_otras_dlag2 → mcomisiones_otras_dlag2_pctl
# ✅ Convertida cforex_dlag2 → cforex_dlag2_pctl
# ✅ Convertida cforex_buy_dlag2 → cforex_buy_dlag2_pctl
# ✅ Convertida mforex_buy_dlag2 → mforex_buy_dlag2_pctl
# ✅ Convertida cforex_sell_dlag2 → cforex_sell_dlag2_pctl
# ✅ Convertida mforex_sell_dlag2 → mforex_sell_dlag2_pctl
# ✅ Convertida ctransferencias_recibidas_dlag2 → ctransferencias_recibidas_dlag2_pctl
# ✅ Convertida mtransferencias_recibidas_dlag2 → mtransferencias_recibidas_dlag2_pctl
# ✅ Convertida ctransferencias_emitidas_dlag2 → ctransferencias_emitidas_dlag2_pctl
# ✅ Convertida mtransferencias_emitidas_dlag2 → mtransferencias_emitidas_dlag2_pctl
# ✅ Convertida cextraccion_autoservicio_dlag2 → cextraccion_autoservicio_dlag2_pctl
# ✅ Convertida mextraccion_autoservicio_dlag2 → mextraccion_autoservicio_dlag2_pctl
# ✅ Convertida ccheques_depositados_dlag2 → ccheques_depositados_dlag2_pctl
# ✅ Convertida mcheques_depositados_dlag2 → mcheques_depositados_dlag2_pctl
# ✅ Convertida ccheques_emitidos_dlag2 → ccheques_emitidos_dlag2_pctl
# ✅ Convertida mcheques_emitidos_dlag2 → mcheques_emitidos_dlag2_pctl
# ✅ Convertida ccheques_depositados_rechazados_dlag2 → ccheques_depositados_rechazados_dlag2_pctl
# ✅ Convertida mcheques_depositados_rechazados_dlag2 → mcheques_depositados_rechazados_dlag2_pctl
# ✅ Convertida ccheques_emitidos_rechazados_dlag2 → ccheques_emitidos_rechazados_dlag2_pctl
# ✅ Convertida mcheques_emitidos_rechazados_dlag2 → mcheques_emitidos_rechazados_dlag2_pctl
# ✅ Convertida tcallcenter_dlag2 → tcallcenter_dlag2_pctl
# ✅ Convertida ccallcenter_transacciones_dlag2 → ccallcenter_transacciones_dlag2_pctl
# ✅ Convertida thomebanking_dlag2 → thomebanking_dlag2_pctl
# ✅ Convertida chomebanking_transacciones_dlag2 → chomebanking_transacciones_dlag2_pctl
# ✅ Convertida ccajas_transacciones_dlag2 → ccajas_transacciones_dlag2_pctl
# ✅ Convertida ccajas_consultas_dlag2 → ccajas_consultas_dlag2_pctl
# ✅ Convertida ccajas_depositos_dlag2 → ccajas_depositos_dlag2_pctl
# ✅ Convertida ccajas_extracciones_dlag2 → ccajas_extracciones_dlag2_pctl
# ✅ Convertida ccajas_otras_dlag2 → ccajas_otras_dlag2_pctl
# ✅ Convertida catm_trx_dlag2 → catm_trx_dlag2_pctl
# ✅ Convertida matm_dlag2 → matm_dlag2_pctl
# ✅ Convertida catm_trx_other_dlag2 → catm_trx_other_dlag2_pctl
# ✅ Convertida matm_other_dlag2 → matm_other_dlag2_pctl
# ✅ Convertida ctrx_quarter_dlag2 → ctrx_quarter_dlag2_pctl
# ✅ Convertida Master_delinquency_dlag2 → Master_delinquency_dlag2_pctl
# ✅ Convertida Master_status_dlag2 → Master_status_dlag2_pctl
# ✅ Convertida Master_mfinanciacion_limite_dlag2 → Master_mfinanciacion_limite_dlag2_pctl
# ✅ Convertida Master_Fvencimiento_dlag2 → Master_Fvencimiento_dlag2_pctl
# ✅ Convertida Master_Finiciomora_dlag2 → Master_Finiciomora_dlag2_pctl
# ✅ Convertida Master_msaldototal_dlag2 → Master_msaldototal_dlag2_pctl
# ✅ Convertida Master_msaldopesos_dlag2 → Master_msaldopesos_dlag2_pctl
# ✅ Convertida Master_msaldodolares_dlag2 → Master_msaldodolares_dlag2_pctl
# ✅ Convertida Master_mconsumospesos_dlag2 → Master_mconsumospesos_dlag2_pctl
# ✅ Convertida Master_mconsumosdolares_dlag2 → Master_mconsumosdolares_dlag2_pctl
# ✅ Convertida Master_mlimitecompra_dlag2 → Master_mlimitecompra_dlag2_pctl
# ✅ Convertida Master_madelantopesos_dlag2 → Master_madelantopesos_dlag2_pctl
# ✅ Convertida Master_madelantodolares_dlag2 → Master_madelantodolares_dlag2_pctl
# ✅ Convertida Master_fultimo_cierre_dlag2 → Master_fultimo_cierre_dlag2_pctl
# ✅ Convertida Master_mpagado_dlag2 → Master_mpagado_dlag2_pctl
# ✅ Convertida Master_mpagospesos_dlag2 → Master_mpagospesos_dlag2_pctl
# ✅ Convertida Master_mpagosdolares_dlag2 → Master_mpagosdolares_dlag2_pctl
# ✅ Convertida Master_fechaalta_dlag2 → Master_fechaalta_dlag2_pctl
# ✅ Convertida Master_mconsumototal_dlag2 → Master_mconsumototal_dlag2_pctl
# ✅ Convertida Master_cconsumos_dlag2 → Master_cconsumos_dlag2_pctl
# ✅ Convertida Master_cadelantosefectivo_dlag2 → Master_cadelantosefectivo_dlag2_pctl
# ✅ Convertida Master_mpagominimo_dlag2 → Master_mpagominimo_dlag2_pctl
# ✅ Convertida Visa_delinquency_dlag2 → Visa_delinquency_dlag2_pctl
# ✅ Convertida Visa_status_dlag2 → Visa_status_dlag2_pctl
# ✅ Convertida Visa_mfinanciacion_limite_dlag2 → Visa_mfinanciacion_limite_dlag2_pctl
# ✅ Convertida Visa_Fvencimiento_dlag2 → Visa_Fvencimiento_dlag2_pctl
# ✅ Convertida Visa_Finiciomora_dlag2 → Visa_Finiciomora_dlag2_pctl
# ✅ Convertida Visa_msaldototal_dlag2 → Visa_msaldototal_dlag2_pctl
# ✅ Convertida Visa_msaldopesos_dlag2 → Visa_msaldopesos_dlag2_pctl
# ✅ Convertida Visa_msaldodolares_dlag2 → Visa_msaldodolares_dlag2_pctl
# ✅ Convertida Visa_mconsumospesos_dlag2 → Visa_mconsumospesos_dlag2_pctl
# ✅ Convertida Visa_mconsumosdolares_dlag2 → Visa_mconsumosdolares_dlag2_pctl
# ✅ Convertida Visa_mlimitecompra_dlag2 → Visa_mlimitecompra_dlag2_pctl
# ✅ Convertida Visa_madelantopesos_dlag2 → Visa_madelantopesos_dlag2_pctl
# ✅ Convertida Visa_madelantodolares_dlag2 → Visa_madelantodolares_dlag2_pctl
# ✅ Convertida Visa_fultimo_cierre_dlag2 → Visa_fultimo_cierre_dlag2_pctl
# ✅ Convertida Visa_mpagado_dlag2 → Visa_mpagado_dlag2_pctl
# ✅ Convertida Visa_mpagospesos_dlag2 → Visa_mpagospesos_dlag2_pctl
# ✅ Convertida Visa_mpagosdolares_dlag2 → Visa_mpagosdolares_dlag2_pctl
# ✅ Convertida Visa_fechaalta_dlag2 → Visa_fechaalta_dlag2_pctl
# ✅ Convertida Visa_mconsumototal_dlag2 → Visa_mconsumototal_dlag2_pctl
# ✅ Convertida Visa_cconsumos_dlag2 → Visa_cconsumos_dlag2_pctl
# ✅ Convertida Visa_cadelantosefectivo_dlag2 → Visa_cadelantosefectivo_dlag2_pctl
# ✅ Convertida Visa_mpagominimo_dlag2 → Visa_mpagominimo_dlag2_pctl
# ✅ Convertida periodo0_dlag2 → periodo0_dlag2_pctl
#
# Total columnas convertidas: 755
# shape: (32, 5)
# ┌──────────┬────────┬────────┬──────────┬────────┐
# │ foto_mes ┆ BAJA+1 ┆ BAJA+2 ┆ CONTINUA ┆ null   │
# │ ---      ┆ ---    ┆ ---    ┆ ---      ┆ ---    │
# │ i64      ┆ u32    ┆ u32    ┆ u32      ┆ u32    │
# ╞══════════╪════════╪════════╪══════════╪════════╡
# │ 201901   ┆ 645    ┆ 729    ┆ 122899   ┆ 0      │
# │ 201902   ┆ 733    ┆ 707    ┆ 123961   ┆ 0      │
# │ 201903   ┆ 708    ┆ 751    ┆ 124508   ┆ 0      │
# │ 201904   ┆ 756    ┆ 514    ┆ 125268   ┆ 0      │
# │ 201905   ┆ 517    ┆ 692    ┆ 125993   ┆ 0      │
# │ …        ┆ …      ┆ …      ┆ …        ┆ …      │
# │ 202104   ┆ 955    ┆ 1130   ┆ 161333   ┆ 0      │
# │ 202105   ┆ 1134   ┆ 842    ┆ 161941   ┆ 0      │
# │ 202106   ┆ 843    ┆ 1134   ┆ 162336   ┆ 0      │
# │ 202107   ┆ 1137   ┆ 0      ┆ 0        ┆ 163459 │
# │ 202108   ┆ 0      ┆ 0      ┆ 0        ┆ 164822 │
# └──────────┴────────┴────────┴──────────┴────────┘
# /tmp/ipykernel_2895/3966937955.py:14: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   .agg(pl.count().alias("cantidad"))
# /tmp/ipykernel_2895/3966937955.py:18: DeprecationWarning: the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.
#   pivot = resumen.pivot(

# %%
train_months = [202101, 202102, 202103,202104,202105]   # meses del conjunto de entrenamiento
undersampling = 0.1                       # proporción de CONTINUA a conservar
seed = 100003                             # semilla reproducible (igual que PARAM$semilla_primigenia)
dataset = undersampling_experimento(dataset,undersampling,train_months,seed)
# Out:
# shape: (2, 2)
# ┌──────────┬────────┐
# │ training ┆ count  │
# │ ---      ┆ ---    │
# │ i32      ┆ u32    │
# ╞══════════╪════════╡
# │ 0        ┆ 724322 │
# │ 1        ┆ 89804  │
# └──────────┴────────┘
# shape: (4, 3)
# ┌──────────┬────────────────┬────────┐
# │ training ┆ clase_ternaria ┆ len    │
# │ ---      ┆ ---            ┆ ---    │
# │ i32      ┆ str            ┆ u32    │
# ╞══════════╪════════════════╪════════╡
# │ 0        ┆ CONTINUA       ┆ 724322 │
# │ 1        ┆ BAJA+1         ┆ 4581   │
# │ 1        ┆ BAJA+2         ┆ 4780   │
# │ 1        ┆ CONTINUA       ┆ 80443  │
# └──────────┴────────────────┴────────┘
