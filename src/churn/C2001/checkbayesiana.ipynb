# %%
PARAM <- list()
PARAM$experimento <- "C2001"
PARAM$semilla_primigenia <- 100271

# %%
experimento_folder <- PARAM$experimento
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
kbayesiana <- "bayesiana.RDATA"

# %%
load(kbayesiana)
print(kbayesiana)
# Out:
# [1] "bayesiana.RDATA"

# %%
ls()
# Out:
# [1] "best_index"         "df"                 "experimento_folder"
# [4] "kbayesiana"         "opt.state"          "PARAM"

# %%
opt.state$loop
# Out:
# [1] 11

# %%
# Convertir a data.frame para inspección
df <- as.data.frame(opt.state$opt.path)

# Ver las primeras filas (cada una es un trial)
head(df)
nrow(df)

# Ver el mejor resultado actual
best_index <- which.min(df$y)  # o which.max(df$y), depende si tu objetivo es minimizar o maximizar
df[best_index, ]
# Out:
#   num_iterations learning_rate feature_fraction min_data_in_leaf num_leaves
# 1 8.993908       -6.311663     0.4529014         3.870240        4.996356
# 2 2.179099       -6.015601     0.5524562        11.422760        3.363918
# 3 7.045822       -3.320548     0.9404752         5.834682        6.281666
# 4 7.564741       -5.691261     0.6760435         2.202581        5.231178
# 5 2.471679       -5.150286     0.4157385         7.415064        3.846972
# 6 3.373986       -1.215982     0.3789695         4.741630        2.868928
#   y         dob eol error.message exec.time ei error.model train.time
# 1 387027756 0   NA  NA            2078.627  NA NA          NA
# 2 314986947 0   NA  NA              97.676  NA NA          NA
# 3 388413403 0   NA  NA             497.023  NA NA          NA
# 4 376363248 0   NA  NA             565.163  NA NA          NA
# 5 325307516 0   NA  NA             101.441  NA NA          NA
# 6 357911754 0   NA  NA             106.877  NA NA          NA
#   prop.type  propose.time se mean
# 1 initdesign NA           NA NA
# 2 initdesign NA           NA NA
# 3 initdesign NA           NA NA
# 4 initdesign NA           NA NA
# 5 initdesign NA           NA NA
# 6 initdesign NA           NA NA
# [1] 30
#    num_iterations learning_rate feature_fraction min_data_in_leaf num_leaves
# 10 3.210459       -7.553139     0.3029318        8.945165         1.010398
#    y         dob eol error.message exec.time ei error.model train.time
# 10 290184488 0   NA  NA            97.825    NA NA          NA
#    prop.type  propose.time se mean
# 10 initdesign NA           NA NA

# %%
nrow(df)
# Out:
# [1] 30
