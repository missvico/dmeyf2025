# %%
PARAM <- list()
PARAM$experimento <- "APO-C2000"
PARAM$semilla_primigenia <- 100271

# %%
experimento_folder <- PARAM$experimento
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
kbayesiana <- "bayesiana.RDATA"

# %%
load(kbayesiana)
print(kbayesiana)
# Out:
# [1] "bayesiana.RDATA"

# %%
ls()
# Out:
# [1] "best_index"         "df"                 "experimento_folder"
# [4] "kbayesiana"         "opt.state"          "PARAM"

# %%
opt.state$loop
# Out:
# [1] 10

# %%
# Convertir a data.frame para inspección
df <- as.data.frame(opt.state$opt.path)

# Ver las primeras filas (cada una es un trial)
head(df)
nrow(df)

# Ver el mejor resultado actual
best_index <- which.min(df$y)  # o which.max(df$y), depende si tu objetivo es minimizar o maximizar
df[best_index, ]
# Out:
#   num_iterations learning_rate feature_fraction min_data_in_leaf num_leaves
# 1 4.869275       -2.827051     0.3625307        11.130451        5.553067
# 2 7.976565       -7.647060     0.7824780         3.570152        3.179809
# 3 5.873140       -5.840207     0.6080368        11.820229        2.736639
# 4 3.801793       -2.164170     0.4704034        12.590377        5.092368
# 5 9.846483       -4.200592     0.1932007         4.788856        7.623582
# 6 2.734099       -4.615601     0.1724562         8.856259        6.513918
#   y         dob eol error.message exec.time ei error.model train.time
# 1 331864188 0   NA  NA             174.493  NA NA          NA
# 2 289695022 0   NA  NA             392.046  NA NA          NA
# 3 288737631 0   NA  NA             161.365  NA NA          NA
# 4 308587376 0   NA  NA             110.145  NA NA          NA
# 5 363236192 0   NA  NA            2999.281  NA NA          NA
# 6 308686717 0   NA  NA              79.808  NA NA          NA
# ...

# %%
nrow(df)
# Out:
# [1] 29
